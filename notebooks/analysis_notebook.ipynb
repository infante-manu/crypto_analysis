# %%
cd '/Users/manuel.infante/Library/CloudStorage/GoogleDrive-minfante.1@alumni.unav.es/My Drive/Repositorios/python-for-data-analysis/crypto_analysis'
# Out:
# /Users/manuel.infante/Library/CloudStorage/GoogleDrive-minfante.1@alumni.unav.es/My Drive/Repositorios/python-for-data-analysis/crypto_analysis

# %%
from crypto_analysis.trading_engine import TradingEngine

# %%
engine = TradingEngine(pair='ETHUSD')
engine.run() 
engine.plot_strategy()
engine.plot_portafolio()

# %%
engine.get_backtest_results().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Initial Capital               1 non-null      int64
#  1   Final Capital                 1 non-null      float64
#  2   Total Trades                  1 non-null      int64
#  3   Winning Trades                1 non-null      int64
#  4   Losing Trades                 1 non-null      int64
#  5   Total Profit                  1 non-null      float64
#  6   Sharpe Ratio                  1 non-null      float64
#  7   Normalized Annual Return (%)  1 non-null      float64
#  8   Max Drawdown (%)              1 non-null      float64
# dtypes: float64(5), int64(4)
# memory usage: 204.0 bytes
